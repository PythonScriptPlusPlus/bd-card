# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# bar chart with two bars
labels = ['aliice', 'Billie Eilish']
values = [127, 64]
plt.figure(figsize=(3, 6))
plt.bar(labels, values, color=['#4B0082', 'green'])
plt.title('Количество постов за год')
plt.margins(y=0.3)
plt.savefig('../src/assets/stats/post_counts.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# artificial pie chart

# %%
plt.pie([60.6, 39.4], colors=["#D32929", 'lightblue'], autopct='%1.1f%%', startangle=210)
plt.savefig('../src/assets/stats/hearts_vs.png', bbox_inches='tight')

# %%
from matplotlib import font_manager

# Try to use a font that supports emojis
emoji_font = None
for font in font_manager.findSystemFonts(fontpaths=None, fontext='ttf'):
    if 'NotoColorEmoji' in font or 'AppleColorEmoji' in font or 'seguiemj' in font:
        emoji_font = font
        break

def emoji_labeler(labels):
    def labelfunc(pct, allvals):
        i = int(pct / 100. * len(labels))
        return labels[i]
    return labelfunc

plt.figure(figsize=(6, 6))
if emoji_font:
    plt.rcParams['font.family'] = font_manager.FontProperties(fname=emoji_font).get_name()
plt.pie(
    reactions_clean['count'],
    labels=reactions_clean['emoji'],
    autopct='%1.1f%%',
    startangle=270
)
plt.title('Emoji Usage Distribution')
plt.axis('equal')
plt.show()
# Out:
# /Users/gatkinson/Library/Python/3.13/lib/python/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 127827 (\N{STRAWBERRY}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/gatkinson/Library/Python/3.13/lib/python/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128330 (\N{DOVE OF PEACE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/gatkinson/Library/Python/3.13/lib/python/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128152 (\N{HEART WITH ARROW}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/gatkinson/Library/Python/3.13/lib/python/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128139 (\N{KISS MARK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
